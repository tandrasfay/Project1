# %% [markdown]
# Use 'stat157.cfg' document to read username, password, and doc ID from file

# %%
import os.path

import ConfigParser

import gspread

home = os.path.expanduser("~")

configfile = os.path.join(home, 'stat157.cfg')

config = ConfigParser.SafeConfigParser()

config.read(configfile)

username = config.get('google', 'username')

password = config.get('google', 'password')

print username

docid = config.get('questionnaire', 'docid')

client = gspread.login(username, password)

spreadsheet = client.open_by_key(docid)

worksheet = spreadsheet.get_worksheet(0)

print docid
# Out:
# lorraineh@berkeley.edu
# 0Aj1QXjQixf-SdENDS1FzR1FGNE1kLUk0WGR1SW5peVE

# %%
fieldnames = ['What is your learning style?','In which of these topics would you feel confident being a technical lead for other students?']

print fieldnames
# Out:
# ['What is your learning style?', 'In which of these topics would you feel confident being a technical lead for other students?']

# %% [markdown]
# Create empty object to store data, and find number of rows within the data.

# %%
filtered_data = []

for row in worksheet.get_all_records():

  filtered_data.append({k:v for k,v in row.iteritems() if k in fieldnames})

print "Number of rows: {}".format(len(filtered_data))
# Out:
# Number of rows: 48

# %% [markdown]
# Print each line of data as a row, and make into a data frame.

# %%
for row in (filtered_data):

  print row

questionnaire = filtered_data

from pandas import DataFrame, read_csv

from xml.etree import ElementTree

import pandas as pd

questdf = DataFrame(questionnaire)
# Out:
# {'In which of these topics would you feel confident being a technical lead for other students?': 'github', 'What is your learning style?': ''}
# {'In which of these topics would you feel confident being a technical lead for other students?': 'github, IPython Notebook or Python', 'What is your learning style?': 'Your scores were:\n\nVisual: 3\nAural: 5\nRead/Write: 4\nKinesthetic: 7\n\nYou have a mild Kinesthetic learning preference.'}
# {'In which of these topics would you feel confident being a technical lead for other students?': 'github, HTML5, Probability, Statistics', 'What is your learning style?': 'I have a multimodal (VAK) learning preference.'}
# {'In which of these topics would you feel confident being a technical lead for other students?': 'Statistics', 'What is your learning style?': 'Your scores were:\n\nVisual: 0\nAural: 10\nRead/Write: 14\nKinesthetic: 5\n\nYou have a mild Read/Write learning preference.'}
# ...

# %% [markdown]
# Here we rename the columns and extract numbers by using regular expressions. We look for the score that comes after each category, searching for a specific name and any punctuation following. Then, we extracted the number that follows. This is applied over the whole data frame, and then the numbers are assigned back into a data frame.

# %%
questdf['Visual'] = questdf['What is your learning style?']

questdf['Aural'] = questdf['What is your learning style?']

questdf['Read/Write'] = questdf['What is your learning style?']

questdf['Kinesthetic'] = questdf['What is your learning style?']

questdf["TechLead"] = questdf["In which of these topics would you feel confident being a technical lead for other students?"]

Style=questdf['What is your learning style?']

import re

def extract(Name,Record,ExtraPattern):

   pattern=Name+'.*[0-9]+'

   if len(ExtraPattern) > 0:

       pattern=pattern+'|'+ExtraPattern+'.*[0-9]+'    # Record no.32 needs special handling

   result=re.findall(pattern,Record)      # Use Regular expression to search

   if len(result) >0:

       result=int(re.findall('[0-9]+',result[0])[0])

   else:

       result= "NA"

   return result
            
Visual = questdf['Visual']

Aural = questdf['Aural']

ReadWrite = questdf['Read/Write']

Kinesthetic = questdf['Kinesthetic']

for i in range(len(Style)):

   Visual[i]= extract("Visual",Style[i],"")

   Aural[i]= extract("Aural",Style[i],"")

   ReadWrite[i]= extract("Read/Write",Style[i],"Reading/Writing")    # Record no.32 needs special handling

   Kinesthetic[i]= extract("Kinesthetic",Style[i],"")

del questdf["What is your learning style?"]

del questdf["In which of these topics would you feel confident being a technical lead for other students?"]

#print questdf

# %% [markdown]
# Create column names for each skill a person is comfortable to be a technical lead in.  Apply a for loop over the data frame, searching for which skills are in each row.  Then insert a 'TRUE' if it is present or a 'FALSE' if it is not.

# %%
SkillList=["github","Python","XML","HTML5","LaTeX","jQuery","Statistics","Probability","R","JavaScript","Blogging","Academic Publishing"]

TechLead=questdf["TechLead"]

for skill in SkillList:

   questdf[skill]=questdf["TechLead"]

   x=questdf[skill]

   for i in range (len(TechLead)):

       x[i]=skill in TechLead[i]

# %% [markdown]
# Combine all into a new table

# %%
print "new table"

#del questdf["TechLead"]

print  questdf
# Out:
# new table
#    Visual Aural Read/Write Kinesthetic  \
# 0      NA    NA         NA          NA
# 1       3     5          4           7
# 2      NA    NA         NA          NA
# 3       0    10         14           5
# 4       9     9          3           3
# 5      NA    NA         NA          NA
# 6       8     7          8           5
# 7       8     1          8           5
# 8      NA    NA         NA          NA
# 9      13    10          8          11
# 10     10     4          5          10
# 11     NA    NA         NA          NA
# 12     15     9          6          11
# 13     NA    NA         NA          NA
# 14      5     1          4           6
# 15      3     6          6           7
# 16     NA    NA         NA          NA
# 17     10    10          2          13
# 18      4     3          1           8
# 19      4     3         11           4
# 20     11    11          6           9
# 21      4     4          7           1
# 22      9     7         10          12
# ...
